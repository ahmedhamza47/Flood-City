# %%
import calendar
from datetime import datetime, timedelta
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import xgboost as xgb
from sklearn.metrics import mean_squared_error


df = pd.read_csv('chisapani_all.csv')

df = df.set_index('dateTime')
df.index = pd.to_datetime(df.index)


train=df.loc[df.index < '01-01-2021']
test=df.loc[df.index >= '01-01-2021']


df['value'] = pd.to_numeric(df['value'], errors='coerce')


df['value'].interpolate()

print(df)

def create_features(df):
    df = df.copy()
    df['hour'] = df.index.hour
    df['dayofweek'] = df.index.dayofweek
    df['quarter'] = df.index.quarter
    df['month'] = df.index.month
    df['year'] = df.index.year
    df['dayofyear'] = df.index.dayofyear
    df['dayofmonth'] = df.index.day
    df['weekofyear'] = df.index.isocalendar().week
    return df

df = create_features(df)

train = create_features(train)
test = create_features(test)

FEATURES = ['dayofyear', 'hour', 'dayofweek', 'quarter', 'month', 'year']
TARGET = 'value'
X_train = train[FEATURES]
y_train = train[TARGET]
X_test = test[FEATURES]
y_test = test[TARGET]
reg = xgb.XGBRegressor(base_score=0.5, booster='gbtree',    
                       n_estimators=10000,
                       early_stopping_rounds=100,
                       objective='reg:linear',
                       max_depth=4,
                       learning_rate=0.001)

reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        verbose=300)


test['prediction'] = reg.predict(X_test)
score = np.sqrt(mean_squared_error(test['value'], test['prediction']))
print(f'RMSE Score on Test set: {score:0.2f}')
# Out:
#                      value
# dateTime
# 2018-01-11 11:30:00  2.240
# 2018-01-22 16:50:00  2.230
# 2018-01-22 17:00:00  2.230
# 2018-01-22 17:10:00  2.230
# 2018-01-22 17:20:00  2.230
# ...                    ...
# 2022-01-01 22:45:00  4.386
# 2022-01-01 23:00:00  4.373
# 2022-01-01 23:15:00  4.375
# 2022-01-01 23:30:00  4.385
# 2022-01-01 23:45:00  4.372
#
# [123977 rows x 1 columns]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 59
#      51 y_test = test[TARGET]
#      52 reg = xgb.XGBRegressor(base_score=0.5, booster='gbtree',
#      53                        n_estimators=10000,
#      54                        early_stopping_rounds=100,
#      55                        objective='reg:linear',
#      56                        max_depth=4,
#      57                        learning_rate=0.001)
# ---> 59 reg.fit(X_train, y_train,
#      60         eval_set=[(X_train, y_train), (X_test, y_test)],
#      61         verbose=300)
#      64 test['prediction'] = reg.predict(X_test)
#      65 score = np.sqrt(mean_squared_error(test['value'], test['prediction']))
#
# File ~/myprojectdir/myprojectenv/lib/python3.9/site-packages/xgboost/core.py:620, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     618 for k, arg in zip(sig.parameters, args):
#     619     kwargs[k] = arg
# --> 620 return func(**kwargs)
#
# File ~/myprojectdir/myprojectenv/lib/python3.9/site-packages/xgboost/sklearn.py:988, in XGBModel.fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#     986 with config_context(verbosity=self.verbosity):
#     987     evals_result: TrainingCallback.EvalsLog = {}
# --> 988     train_dmatrix, evals = _wrap_evaluation_matrices(
#     989         missing=self.missing,
#     990         X=X,
#     991         y=y,
#     992         group=None,
#     993         qid=None,
#     994         sample_weight=sample_weight,
#     995         base_margin=base_margin,
#     996         feature_weights=feature_weights,
#     997         eval_set=eval_set,
#     998         sample_weight_eval_set=sample_weight_eval_set,
#     999         base_margin_eval_set=base_margin_eval_set,
#    1000         eval_group=None,
#    1001         eval_qid=None,
#    1002         create_dmatrix=self._create_dmatrix,
#    1003         enable_categorical=self.enable_categorical,
#    1004         feature_types=self.feature_types,
#    1005     )
#    1006     params = self.get_xgb_params()
#    1008     if callable(self.objective):
#
# File ~/myprojectdir/myprojectenv/lib/python3.9/site-packages/xgboost/sklearn.py:448, in _wrap_evaluation_matrices(missing, X, y, group, qid, sample_weight, base_margin, feature_weights, eval_set, sample_weight_eval_set, base_margin_eval_set, eval_group, eval_qid, create_dmatrix, enable_categorical, feature_types)
#     428 def _wrap_evaluation_matrices(
#     429     missing: float,
#     430     X: Any,
#    (...)
#     444     feature_types: Optional[FeatureTypes],
#     445 ) -> Tuple[Any, List[Tuple[Any, str]]]:
#     446     """Convert array_like evaluation matrices into DMatrix.  Perform validation on the
#     447     way."""
# --> 448     train_dmatrix = create_dmatrix(
#     449         data=X,
#     450         label=y,
#     451         group=group,
#     452         qid=qid,
#     453         weight=sample_weight,
#     454         base_margin=base_margin,
#     455         feature_weights=feature_weights,
#     456         missing=missing,
#     457         enable_categorical=enable_categorical,
#     458         feature_types=feature_types,
#     459         ref=None,
#     460     )
#     462     n_validation = 0 if eval_set is None else len(eval_set)
#     464     def validate_or_none(meta: Optional[Sequence], name: str) -> Sequence:
#
# File ~/myprojectdir/myprojectenv/lib/python3.9/site-packages/xgboost/sklearn.py:908, in XGBModel._create_dmatrix(self, ref, **kwargs)
#     906     except TypeError:  # `QuantileDMatrix` supports lesser types than DMatrix
#     907         pass
# --> 908 return DMatrix(**kwargs, nthread=self.n_jobs)
#
# File ~/myprojectdir/myprojectenv/lib/python3.9/site-packages/xgboost/core.py:620, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     618 for k, arg in zip(sig.parameters, args):
#     619     kwargs[k] = arg
# --> 620 return func(**kwargs)
#
# File ~/myprojectdir/myprojectenv/lib/python3.9/site-packages/xgboost/core.py:754, in DMatrix.__init__(self, data, label, weight, base_margin, missing, silent, feature_names, feature_types, nthread, group, qid, label_lower_bound, label_upper_bound, feature_weights, enable_categorical)
#     751 assert handle is not None
#     752 self.handle = handle
# --> 754 self.set_info(
#     755     label=label,
#     756     weight=weight,
#     757     base_margin=base_margin,
#     758     group=group,
#     759     qid=qid,
#     760     label_lower_bound=label_lower_bound,
#     761     label_upper_bound=label_upper_bound,
#     762     feature_weights=feature_weights,
#     763 )
#     765 if feature_names is not None:
#     766     self.feature_names = feature_names
#
# File ~/myprojectdir/myprojectenv/lib/python3.9/site-packages/xgboost/core.py:620, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     618 for k, arg in zip(sig.parameters, args):
#     619     kwargs[k] = arg
# --> 620 return func(**kwargs)
#
# File ~/myprojectdir/myprojectenv/lib/python3.9/site-packages/xgboost/core.py:819, in DMatrix.set_info(self, label, weight, base_margin, group, qid, label_lower_bound, label_upper_bound, feature_names, feature_types, feature_weights)
#     816 from .data import dispatch_meta_backend
#     818 if label is not None:
# --> 819     self.set_label(label)
#     820 if weight is not None:
#     821     self.set_weight(weight)
#
# File ~/myprojectdir/myprojectenv/lib/python3.9/site-packages/xgboost/core.py:950, in DMatrix.set_label(self, label)
#     942 """Set label of dmatrix
#     943
#     944 Parameters
#    (...)
#     947     The label information to be set into DMatrix
#     948 """
#     949 from .data import dispatch_meta_backend
# --> 950 dispatch_meta_backend(self, label, 'label', 'float')
#
# File ~/myprojectdir/myprojectenv/lib/python3.9/site-packages/xgboost/data.py:1121, in dispatch_meta_backend(matrix, data, name, dtype)
#    1119     return
#    1120 if _is_pandas_series(data):
# -> 1121     _meta_from_pandas_series(data, name, dtype, handle)
#    1122     return
#    1123 if _is_dlpack(data):
#
# File ~/myprojectdir/myprojectenv/lib/python3.9/site-packages/xgboost/data.py:425, in _meta_from_pandas_series(data, name, dtype, handle)
#     418 def _meta_from_pandas_series(
#     419     data: DataType,
#     420     name: str,
#     421     dtype: Optional[NumpyDType],
#     422     handle: ctypes.c_void_p
#     423 ) -> None:
#     424     """Help transform pandas series for meta data like labels"""
# --> 425     data = data.values.astype('float')
#     426     from pandas.api.types import is_sparse
#     427     if is_sparse(data):
#
# ValueError: could not convert string to float: ''
